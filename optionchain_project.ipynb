# %%
import urllib.parse
import pandas as pd
import requests

# %%
apiKey = 'your_apiKey'
secretKey ='Your_secretkey'
rurl = urllib.parse.quote('https://127.0.0.1:5000/',safe="")

# %%
uri = f"https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id={apiKey}&redirect_uri={rurl}"

# %%
uri
# Out:
# 'https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id=c1643bc9-9228-4275-964d-ef030237ecfe&redirect_uri=https%3A%2F%2F127.0.0.1%3A5000%2F'

# %%
code='2xorXd'

# %%
access_token=json_response['access_token']
access_token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiIySEM1N0oiLCJqdGkiOiI2NzI0ZDgyY2NhZjc2ZDUzNzg0YzI3MzIiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaWF0IjoxNzMwNDY3ODg0LCJpc3MiOiJ1ZGFwaS1nYXRld2F5LXNlcnZpY2UiLCJleHAiOjE3MzA0OTg0MDB9.-gCyLuLP2t0wWqoRBmUs0DHPDx9M1PtQLbCRJp_B5-Y'

# %%
url = 'https://api.upstox.com/v2/user/get-funds-and-margin' 
headers = {
    'accept':'application/json',
    'Api-Version':'2.0',
    'Authorization':f'Bearer {access_token}'
}
params = {
    'segment':'COM'
}
response = requests.get(url, headers=headers, params = params)
response.json()
# Out:
# {'status': 'success',
#  'data': {'commodity': {'used_margin': 0.0,
#    'payin_amount': 0.0,
#    'span_margin': 0.0,
#    'adhoc_margin': 0.0,
#    'notional_cash': 0.0,
#    'available_margin': 0.0,
#    'exposure_margin': 0.0}}}

# %%
fileUrl ='https://assets.upstox.com/market-quote/instruments/exchange/complete.csv.gz'
symboldf = pd.read_csv(fileUrl)
symboldf['expiry'] = pd.to_datetime(symboldf['expiry']).apply(lambda x: x.date())
symboldf
# Out:
#                     instrument_key  exchange_token      tradingsymbol  \
# 0               NSE_INDEX|Nifty 50            17.0                NaN
# 1       NSE_INDEX|NIFTY100 EQL Wgt             NaN                NaN
# 2        NSE_INDEX|NIFTY50 EQL Wgt             NaN                NaN
# 3      NSE_INDEX|NiftyM150Momntm50             NaN                NaN
# 4             NSE_INDEX|Nifty Auto            48.0                NaN
# ...                            ...             ...                ...
# 80832               BCD_FO|1081146       1081146.0  USDINR24D1386.4PE
# 80833               BCD_FO|1081147       1081147.0  USDINR24D1386.6CE
# 80834               BCD_FO|1081148       1081148.0  USDINR24D1386.6PE
# 80835               BCD_FO|1081149       1081149.0  USDINR24D1386.7CE
# 80836               BCD_FO|1081150       1081150.0  USDINR24D1386.7PE
#
#                     name  last_price      expiry  strike  tick_size  lot_size  \
# ...

# %%
symboldf.to_csv('completedata.csv', index=False)

# %%
#datapreprocessing
import pandas as pd
df = pd.read_csv('completedata.csv')

# Drop rows where 'name', 'expiry', or 'option_type' columns have missing values
df_cleaned = df.dropna(subset=['name', 'expiry', 'option_type'])

# Displaying the cleaned data
print(df_cleaned.head())

# save the cleaned data to a new CSV file
df_cleaned.to_csv('completepreprocesseddata.csv', index=False)
# Out:
#       instrument_key  exchange_token       tradingsymbol        name  \
# 48928  MCX_FO|437991        437991.0      COPPER24DECFUT      COPPER
# 48929  MCX_FO|441834        441834.0  NATGASMINI25APRFUT  NATURALGAS
# 48930  MCX_FO|438426        438426.0  MCXMETLDEX24NOVFUT  MCXMETLDEX
# 48931  MCX_FO|434271        434271.0    CRUDEOIL24NOVFUT   CRUDE OIL
# 48932  MCX_FO|442162        442162.0    LEADMINI25MARFUT        LEAD
#
#        last_price      expiry  strike  tick_size  lot_size instrument_type  \
# 48928       841.7  31-12-2024     0.0        5.0    2500.0          FUTCOM
# 48929       346.5  25-04-2025     0.0       10.0     250.0          FUTCOM
# 48930         0.0  20-11-2024     0.0      100.0      50.0          FUTCOM
# 48931      5823.0  19-11-2024     0.0      100.0     100.0          FUTCOM
# 48932         0.0  31-03-2025     0.0        5.0       1.0          FUTCOM
#
#       option_type exchange
# 48928          FF   MCX_FO
# 48929          FF   MCX_FO
# ...

# %%
df_cleaned.shape
# Out:
# (15352, 12)

# %%
def get_option_chain_data(instrument_name: str, expiry_date: str, side: str) -> pd.DataFrame:
    # Convert expiry_date to date format
    expiry_date = pd.to_datetime(expiry_date, format='%d-%m-%Y').date()
    
    # Filtering using 'name'  and adjust the expiry date format
    options = df_cleaned[(df_cleaned['name'] == instrument_name) & 
                         (pd.to_datetime(df_cleaned['expiry'], format='%d-%m-%Y').dt.date == expiry_date) & 
                         (df_cleaned['option_type'] == side)]
    
    if options.empty:
        print(f"No matching options found for {instrument_name} with expiry {expiry_date} and side {side}.")
        return pd.DataFrame(columns=['instrument_name', 'strike_price', 'side', 'bid/ask'])

    # Collecting the highest prices for each strike
    output_data = []
    if side == 'PE':
        highest_bid = options['last_price'].max()
        for strike in options['strike'].unique():
            output_data.append({
                'instrument_name': instrument_name,
                'strike_price': strike,
                'side': side,
                'bid/ask': highest_bid
            })
    elif side == 'CE':
        highest_ask = options['last_price'].max()
        for strike in options['strike'].unique():
            output_data.append({
                'instrument_name': instrument_name,
                'strike_price': strike,
                'side': side,
                'bid/ask': highest_ask
            })

    output_df = pd.DataFrame(output_data)
    return output_df

# Usage
instrument_name = "NATURALGAS"
expiry_date = "23-12-2024"
side = "PE"

# Call function
option_chain_df = get_option_chain_data(instrument_name, expiry_date, side)
print("Option Chain Data:")
print(option_chain_df.to_string(index=False))

# Usage
instrument_name = "NATURALGAS"
expiry_date = "23-12-2024"
side = "CE"

# Call function
option_chain_df = get_option_chain_data(instrument_name, expiry_date, side)
print("Option Chain Data:")
print(option_chain_df.to_string(index=False))
# Out:
# Option Chain Data:
# instrument_name  strike_price side  bid/ask
#      NATURALGAS         215.0   PE   117.15
#      NATURALGAS         255.0   PE   117.15
#      NATURALGAS         280.0   PE   117.15
#      NATURALGAS         260.0   PE   117.15
#      NATURALGAS         325.0   PE   117.15
#      NATURALGAS         340.0   PE   117.15
#      NATURALGAS         195.0   PE   117.15
#      NATURALGAS         370.0   PE   117.15
#      NATURALGAS         190.0   PE   117.15
#      NATURALGAS         270.0   PE   117.15
#      NATURALGAS         380.0   PE   117.15
#      NATURALGAS         300.0   PE   117.15
#      NATURALGAS         250.0   PE   117.15
#      NATURALGAS         305.0   PE   117.15
#      NATURALGAS         185.0   PE   117.15
#      NATURALGAS         175.0   PE   117.15
#      NATURALGAS         240.0   PE   117.15
#      NATURALGAS         295.0   PE   117.15
#      NATURALGAS         310.0   PE   117.15
#      NATURALGAS         320.0   PE   117.15
# ...

# %%
import pandas as pd

# Mock function to simulate fetching margin requirement from an API
def get_margin_requirement(instrument_name: str, strike_price: float, side: str) -> float:
    # Simulated margin requirement logic (for demonstration, using a constant or simple calculation)
    return strike_price * 0.10

def calculate_margin_and_premium(data: pd.DataFrame, lot_size: int) -> pd.DataFrame:
    # Check if the DataFrame is empty
    if data.empty:
        print("No data available to calculate margin and premium.")
        return data

    # Calculate margin required and premium earned
    data['margin_required'] = data.apply(
        lambda row: get_margin_requirement(row['instrument_name'], row['strike_price'], row['side']), axis=1)
    data['premium_earned'] = data['bid/ask'] * lot_size

    return data

# Example usage
lot_size = 10  # Assuming a lot size of 10 for this example
option_chain_df_with_margin = calculate_margin_and_premium(option_chain_df, lot_size)


# Print the resulting DataFrame
print("Option Chain Data with Margin and Premium:")
print(option_chain_df_with_margin.to_string(index=False))
# Out:
# Option Chain Data with Margin and Premium:
# instrument_name  strike_price side  bid/ask  margin_required  premium_earned
#      NATURALGAS         215.0   PE   117.15             21.5          1171.5
#      NATURALGAS         255.0   PE   117.15             25.5          1171.5
#      NATURALGAS         280.0   PE   117.15             28.0          1171.5
#      NATURALGAS         260.0   PE   117.15             26.0          1171.5
#      NATURALGAS         325.0   PE   117.15             32.5          1171.5
#      NATURALGAS         340.0   PE   117.15             34.0          1171.5
#      NATURALGAS         195.0   PE   117.15             19.5          1171.5
#      NATURALGAS         370.0   PE   117.15             37.0          1171.5
#      NATURALGAS         190.0   PE   117.15             19.0          1171.5
#      NATURALGAS         270.0   PE   117.15             27.0          1171.5
#      NATURALGAS         380.0   PE   117.15             38.0          1171.5
# ...
